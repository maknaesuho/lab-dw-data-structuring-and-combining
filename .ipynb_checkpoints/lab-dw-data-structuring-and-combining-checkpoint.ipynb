# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd
url1 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv'
customer_data_1 = pd.read_csv(url1)
customer_data_1.columns = customer_data_1.columns.str.lower().str.replace(" ","_")
customer_data_1.rename(columns={'st': 'state'}, inplace=True)

# %%
url2 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv'
customer_data_2 = pd.read_csv(url2)
customer_data_2.columns = customer_data_2.columns.str.lower().str.replace(" ","_")
customer_data_2.rename(columns={'st': 'state'}, inplace=True)

# %%
url3 = 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv'
customer_data_3 = pd.read_csv(url3)
customer_data_3.columns = customer_data_3.columns.str.lower().str.replace(" ","_")

# %%
customer_data = pd.concat([customer_data_1, customer_data_2, customer_data_3], axis=0, ignore_index=True)

# %%
customer_data.drop_duplicates(inplace=True)

# %% [raw]
# Changing data types to numeric

# %%
customer_data['customer_lifetime_value'] = customer_data['customer_lifetime_value'].astype(str).str.replace('%', '')
customer_data['customer_lifetime_value'] = pd.to_numeric(customer_data['customer_lifetime_value'], errors='coerce')

# %%
customer_data['number_of_open_complaints'] = customer_data['number_of_open_complaints'].astype(str).str.split('/').str[1]
customer_data['number_of_open_complaints'] = pd.to_numeric(customer_data['number_of_open_complaints'], errors='coerce')

# %%
customer_data
# Out:
#       customer       state   gender             education  \
# 0      RB50392  Washington  Unknown                Master
# 1      QZ44356     Arizona        F              Bachelor
# 2      AI49188      Nevada        F              Bachelor
# 3      WW63253  California        M              Bachelor
# 4      GA49547  Washington        M  High School or Below
# ...        ...         ...      ...                   ...
# 12069  LA72316  California        M              Bachelor
# 12070  PK87824  California        F               College
# 12071  TD14365  California        M              Bachelor
# 12072  UP19263  California        M               College
# 12073  Y167826  California        M               College
#
#        customer_lifetime_value   income  monthly_premium_auto  \
# 0                          NaN      0.0                1000.0
# 1                 6.979536e+05      0.0                  94.0
# 2                 1.288743e+06  48767.0                 108.0
# ...

# %% [raw]
# Cleaning the Gender, State and Education cells

# %%
customer_data["gender"] = customer_data["gender"].replace("Male", "M")
customer_data["gender"] = customer_data["gender"].replace(["female", "Femal"], "F")

# %%
customer_data["state"] = customer_data["state"].replace("AZ", "Arizona")
customer_data["state"] = customer_data["state"].replace("WA", "Washington")
customer_data["state"] = customer_data["state"].replace("Cali", "California")
customer_data["education"] = customer_data["education"].replace("Bachelors", "Bachelor")

# %%
customer_data.isna().sum() #number_of_open_complaints are not NaN but it is zero.
# Out:
# customer                        1
# state                           1
# gender                          0
# education                       1
# customer_lifetime_value         8
# income                          1
# monthly_premium_auto            1
# number_of_open_complaints    7071
# policy_type                     1
# vehicle_class                   1
# total_claim_amount              1
# dtype: int64

# %%
# even though gender might not be relevant, the numbers associated with a customer are still needed
customer_data["gender"] = customer_data["gender"].fillna("Unknown")

# %%
customer_data.dropna(subset=['customer_lifetime_value'], inplace = True) 
# only 8 values, very small amount in comparison to row number, null values can be dropped without affecting the stats

# %%
customer_data.isna().sum()
# Out:
# customer                        0
# state                           0
# gender                          0
# education                       0
# customer_lifetime_value         0
# income                          0
# monthly_premium_auto            0
# number_of_open_complaints    7070
# policy_type                     0
# vehicle_class                   0
# total_claim_amount              0
# dtype: int64

# %%
customer_data.head(20)
# Out:
#    customer       state   gender             education  \
# 1   QZ44356     Arizona        F              Bachelor
# 2   AI49188      Nevada        F              Bachelor
# 3   WW63253  California        M              Bachelor
# 4   GA49547  Washington        M  High School or Below
# 5   OC83172      Oregon        F              Bachelor
# 6   XZ87318      Oregon        F               College
# 7   CF85061     Arizona        M                Master
# 8   DY87989      Oregon        M              Bachelor
# 9   BQ94931      Oregon        F               College
# 10  SX51350  California        M               College
# 11  VQ65197  California  Unknown               College
# 12  DP39365  California  Unknown                Master
# 13  SJ95423     Arizona  Unknown  High School or Below
# 14  IL66569  California  Unknown               College
# 15  BW63560      Oregon  Unknown              Bachelor
# 16  FV94802      Nevada  Unknown  High School or Below
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
url_new= 'https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv'
marketing_customer_analysis = pd.read_csv(url_new)

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
marketing_customer_analysis.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='str')

# %%
# Total revenue per sales channel
total_revenue = marketing_customer_analysis.pivot_table(index='sales_channel', values='customer_lifetime_value', aggfunc='sum').round(2)

percentage = (total_revenue['customer_lifetime_value'] / total_revenue['customer_lifetime_value'].sum() * 100)
print(percentage.round(2))
# Out:
# sales_channel
# Agent          37.79
# Branch         27.85
# Call Center    19.85
# Web            14.52
# Name: customer_lifetime_value, dtype: float64

# %% [raw]
# The Agent and Branch channels account for the largest share of total revenue (37.79% and 27.85%) compared to Call Center and Web.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_df = marketing_customer_analysis.pivot_table(index=['education'], columns='gender', values=['customer_lifetime_value'], aggfunc='mean')

# %%
pivot_df
# Out:
#                      customer_lifetime_value
# gender                                     F            M
# education
# Bachelor                         7874.269478  7703.601675
# College                          7748.823325  8052.459288
# Doctor                           7328.508916  7415.333638
# High School or Below             8675.220201  8149.687783
# Master                           8157.053154  8168.832659

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
pivot_df2 = marketing_customer_analysis.pivot_table(index='policy_type', columns='month', values='number_of_open_complaints', aggfunc='sum')

# %%
pivot_df2
# Out:
# month              February      January
# policy_type
# Corporate Auto   385.208135   443.434952
# Personal Auto   1453.684441  1727.605722
# Special Auto      95.226817    87.074049
